# %% [markdown]
# # <span style="font-width:bold; font-size: 3rem; color:#333;">Training Pipeline</span>
#
# ## 🗒️ This notebook is divided into the following sections:
#
# 1. Select features for the model and create a Feature View with the selected features
# 2. Create training data using the feature view
# 3. Train model
# 4. Evaluate model performance
# 5. Save model to model registry

# %% [markdown]
# ### <span style='color:#ff5f27'> 📝 Imports

# %%
import pandas as pd
import numpy as np
from collections import Counter
import os
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score
from xgboost import XGBClassifier, plot_importance
import xgboost as xgb
from util.helper import * 
import util.helper as helpfun
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %% [markdown]
# ## <span style="color:#ff5f27;"> Prepare training features</span>

# %%
# Get current working directory
current_dir = os.getcwd()
print(f"Current directory: {current_dir}")
# Out:
# Current directory: C:\Users\marth\OneDrive - KTH\[Y1] Period 2\ID2223 Scalable Machine Learning and Deep Learning\Projects\Final Pj\ID2223-Final-Project

# %%
model_path = os.path.join(current_dir, 'model', 'champion_predictor.json')
label_encoder_path = os.path.join(current_dir, 'model', 'label_encoder.joblib')

# Load the label encoder first to get number of classes
label_encoder = joblib.load(label_encoder_path)
n_classes = len(label_encoder.classes_)

# Initialize the model with proper parameters
model = xgb.XGBClassifier(
    use_label_encoder=False,
    objective='multi:softprob',
    num_class=n_classes
)

# Load the model
model._Booster = xgb.Booster()
model._Booster.load_model(model_path)

# Set only n_classes_
model.n_classes_ = n_classes
# Out:
# C:\Users\marth\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator LabelEncoder from version 1.6.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
meta_stats_path =  os.path.join(current_dir, 'util', 'data', 'meta_stats.csv')
meta_stats = pd.read_csv(meta_stats_path)
print(meta_stats)
# Out:
#      rank    champion  tier     role  win_rate  pick_rate  ban_rate  \
# 0       1       Riven     1      top    0.5279     0.0502    0.0300
# 1       2      Irelia     1      top    0.5177     0.0610    0.1392
# 2       3      Darius     1      top    0.5148     0.0763    0.1494
# 3       4  Cassiopeia     1      top    0.5511     0.0118    0.0119
# 4       5      Aatrox     2      top    0.5011     0.0837    0.0939
# ..    ...         ...   ...      ...       ...        ...       ...
# 230    40     LeBlanc     5  support    0.4784     0.0070    0.0240
# 231    41        Shen     5  support    0.4901     0.0050    0.0006
# 232    42     Camille     5  support    0.4799     0.0056    0.0026
# 233    43        Hwei     5  support    0.4720     0.0077    0.0067
# 234    44       Sylas     5  support    0.4609     0.0118    0.0102
#
#          counter1    counter2 counter3
# 0      Cassiopeia       Urgot     Olaf
# 1            Olaf       Riven   Wukong
# 2            Udyr       Teemo    Quinn
# 3            Sion   Dr. Mundo     Sett
# 4    Heimerdinger  Cassiopeia     Kled
# ..            ...         ...      ...
# 230         Janna      Thresh     Bard
# 231          Lulu        Pyke   Thresh
# 232          Rell        Nami    Karma
# 233         Senna        Lulu     Rell
# 234         Janna       Poppy    Karma
#
# [235 rows x 10 columns]

# %%
weekly_meta_stats_path =  os.path.join(current_dir, 'util', 'data', 'weekly_meta_stats.csv')
weekly_meta_stats = pd.read_csv(weekly_meta_stats_path)
print(weekly_meta_stats)
# Out:
#      rank champion  games   KDA     WR   pick    ban      cs   gold
# 0       1    Viego    602  3.22  52.66  27.44  21.73  178.51  11737
# 1       2   Viktor    581  2.52  51.81  26.48  36.53  206.93  11327
# 2       3    Corki    493  2.65  52.13  22.47  13.07  215.03  11859
# 3       4    Jayce    484  2.13  51.03  22.06   6.11  189.65  10715
# 4       5   Ezreal    404  2.60  46.29  18.41   7.74  199.91  11054
# ..    ...      ...    ...   ...    ...    ...    ...     ...    ...
# 164   165    Nasus     14  1.80   0.50   0.64   1.96  172.43  10215
# 165   166  Naafiri     12  1.84  33.33   0.55   0.26  176.83  10013
# 166   167    Quinn     11  1.45  36.36   0.51   0.77  148.82  10563
# 167   168   Illaoi     11  1.46  27.27   0.05   0.13  225.18  12160
# 168   169   Yorick      9  1.02  44.44   0.41   0.53  178.00   9785
#
# [169 rows x 9 columns]

# %%
player_data_path = os.path.join(current_dir, 'util', 'data', 'feature_eng_stats.csv')
player_data = pd.read_csv(player_data_path)

# %%
pdata_df = convert_df(player_data)
# Out:
# Dropped 0 rows with NA champion values
# Applying convert_team_colors...
# Applying convert_region...
# Applying convert_champion_columns...
# Applying convert_date_column...
# Applying convert_role_columns...
# Applying convert_id_columns...
# Applying remove_match_stats...

# %%
pdata_df = apply_feature_engineering(pdata_df)
# Out:
# Applying calculate_champ_variety_score...
# Applying calculate_playstyle...
# Applying get_most_role_3...
# Applying calculate_role_specialization...
# Applying calculate_champion_loyalty...
# Applying <lambda>...
# Applying remove_unwanted_columns...
# Removed 306 columns
# Remaining columns: 39
# Applying optimize_feature_dtypes...

# %%
check_datatypes(pdata_df)
# Out:
#                                dtype  unique_values
# champion                       UInt8             37
# region                      category              4
# team_champ1                    UInt8             49
# team_champ2                    UInt8             53
# team_champ3                    UInt8             43
# team_champ4                    UInt8             40
# opp_champ1                     UInt8             41
# opp_champ2                     UInt8             33
# opp_champ3                     UInt8             41
# opp_champ4                     UInt8             31
# opp_champ5                     UInt8             34
# avg_kills                    float32              5
# avg_deaths                   float32              5
# avg_assists                  float32              5
# kda_ratio_profile            float32              5
# kill_participation_profile   float32              5
# most_champ_1                   UInt8              5
# most_champ_2                   UInt8              5
# most_role_1                 category              4
# most_role_2                 category              3
# most_role_1_value            float32              3
# most_role_2_value            float32              4
# season_champ_1               float64              4
# season_champ_2               float64              4
# season_champ_3               float64              4
# champ_variety_score         category              2
# playstyle                   category              4
# most_role_3                 category              4
# most_role_3_value            float32              3
# role_specialization         category              2
# champion_loyalty_score       float32              3
# loyalty_confidence_score     float32              2
# recent_champ_1_loyal        category              2
# recent_champ_2_loyal        category              2
# 1_champ_name                   UInt8              7
# 2_champ_name                   UInt8              8
# 3_champ_name                   UInt8              7
# 4_champ_name                   UInt8              8
# 5_champ_name                   UInt8             11
#                                dtype  unique_values
# champion                       UInt8             37
# region                      category              4
# team_champ1                    UInt8             49
# team_champ2                    UInt8             53
# team_champ3                    UInt8             43
# team_champ4                    UInt8             40
# opp_champ1                     UInt8             41
# opp_champ2                     UInt8             33
# opp_champ3                     UInt8             41
# opp_champ4                     UInt8             31
# opp_champ5                     UInt8             34
# avg_kills                    float32              5
# avg_deaths                   float32              5
# avg_assists                  float32              5
# kda_ratio_profile            float32              5
# kill_participation_profile   float32              5
# most_champ_1                   UInt8              5
# most_champ_2                   UInt8              5
# most_role_1                 category              4
# most_role_2                 category              3
# most_role_1_value            float32              3
# most_role_2_value            float32              4
# season_champ_1               float64              4
# season_champ_2               float64              4
# season_champ_3               float64              4
# champ_variety_score         category              2
# playstyle                   category              4
# most_role_3                 category              4
# most_role_3_value            float32              3
# role_specialization         category              2
# champion_loyalty_score       float32              3
# loyalty_confidence_score     float32              2
# recent_champ_1_loyal        category              2
# recent_champ_2_loyal        category              2
# 1_champ_name                   UInt8              7
# 2_champ_name                   UInt8              8
# 3_champ_name                   UInt8              7
# 4_champ_name                   UInt8              8
# 5_champ_name                   UInt8             11

# %%
label_column = pdata_df['champion']

# %%
predict_column = pdata_df.drop(columns=['champion', 'region']) #I think forgot to remove region

# %%
def predict_top_5_with_confidence(model, X, y_true, label_encoder, champion_converter):
    """
    Predict top 5 champions with confidence scores and compare with true label
    Returns a DataFrame with true champion, predicted champions and their confidence scores
    """
    # Get probabilities
    proba = model.predict_proba(X)
    
    # Get top 5 indices and probabilities
    top_5_idx = np.argsort(proba, axis=1)[:, -5:][:, ::-1]
    top_5_proba = np.take_along_axis(proba, top_5_idx, axis=1)
    
    # Initialize results DataFrame
    results = pd.DataFrame()
    
    # Add true champion - convert numeric label to champion name
    true_numbers = y_true
    results['True_Champion'] = [champion_converter.num_to_champion(int(num)) for num in true_numbers]
    
    # Process each rank separately
    for i in range(5):
        # Convert indices to champion names using the champion converter
        champions = [champion_converter.num_to_champion(int(label_encoder.classes_[idx])) for idx in top_5_idx[:, i]]
        probabilities = top_5_proba[:, i]
        
        # Add to results
        results[f'Rank_{i+1}_Champion'] = champions
        results[f'Rank_{i+1}_Confidence'] = probabilities.round(4)
    
    # Find which rank the true champion appeared in (if any)
    def find_champion_rank(row):
        true_champ = row['True_Champion']
        for i in range(1, 6):
            if row[f'Rank_{i}_Champion'] == true_champ:
                return f'Rank_{i}'
        return 'Not in Top 5'
    
    results['Prediction_Rank'] = results.apply(find_champion_rank, axis=1)
    
    return results

# %%
champion_converter = ChampionConverter()

# Make predictions
results = predict_top_5_with_confidence(
    model=model,
    X=predict_column,
    y_true=label_column,
    label_encoder=label_encoder,
    champion_converter=champion_converter
)

# %%
# Print results in a nice format
print("\nPrediction Results:")
print("-" * 100)
print(results.to_string(index=False))
print("-" * 100)

# Print summary statistics
rank_distribution = results['Prediction_Rank'].value_counts().sort_index()
print("\nPrediction Rank Distribution:")
for rank, count in rank_distribution.items():
    print(f"{rank}: {count} ({count/len(results):.1%})")

# Calculate accuracy metrics
in_top_1 = (results['Prediction_Rank'] == 'Rank_1').mean()
in_top_3 = results['Prediction_Rank'].isin(['Rank_1', 'Rank_2', 'Rank_3']).mean()
in_top_5 = results['Prediction_Rank'].isin(['Rank_1', 'Rank_2', 'Rank_3', 'Rank_4', 'Rank_5']).mean()

print(f"\nAccuracy Metrics:")
print(f"Top 1 Accuracy: {in_top_1:.2%}")
print(f"Top 3 Accuracy: {in_top_3:.2%}")
print(f"Top 5 Accuracy: {in_top_5:.2%}")

# Print detailed predictions for each instance
print("\nDetailed Predictions:")
# Rank 2: Jinx (6.6%)
# Rank 3: Varus (4.2%)
# Rank 4: Kai'Sa (3.6%)
# Rank 5: Jhin (3.6%)
#
# Instance 9:
# True Champion: Jarvan IV
# Found in: Not in Top 5
# Rank 1: Jinx (10.6%)
# Rank 2: Ashe (6.6%)
# Rank 3: Varus (5.0%)
# Rank 4: Ezreal (4.7%)
# Rank 5: Elise (4.5%)
#
# Instance 10:
# True Champion: Wukong
# Found in: Not in Top 5
# Rank 1: Varus (8.9%)
# Rank 2: Jinx (8.4%)
# Rank 3: Elise (5.9%)
# Rank 4: Jhin (5.5%)
# Rank 5: Caitlyn (3.2%)
#
# Instance 11:
# True Champion: Wukong
# Found in: Not in Top 5
# Rank 1: Varus (12.1%)
# Rank 2: Jinx (8.1%)
# Rank 3: Ashe (7.2%)
# Rank 4: Jhin (4.7%)
# Rank 5: Kai'Sa (4.1%)
#
# Instance 12:
# True Champion: Karma
# Found in: Not in Top 5
# Rank 1: Jinx (14.6%)
# Rank 2: Ashe (6.0%)
# Rank 3: Elise (4.4%)
# Rank 4: Kai'Sa (4.1%)
# Rank 5: Varus (4.0%)
#
# Instance 13:
# True Champion: Jarvan IV
# Found in: Not in Top 5
# Rank 1: Jinx (6.6%)
# Rank 2: Varus (6.1%)
# Rank 3: Kai'Sa (5.5%)
# Rank 4: Jhin (5.4%)
# Rank 5: Ashe (5.1%)
#
# Instance 14:
# True Champion: Elise
# Found in: Rank_3
# Rank 1: Jinx (10.1%)
# Rank 2: Ashe (7.6%)
# Rank 3: Elise (5.1%)
# Rank 4: Varus (4.6%)
# Rank 5: Jhin (3.9%)
#
# Instance 15:
# True Champion: Elise
# Found in: Rank_5
# Rank 1: Jinx (9.5%)
# Rank 2: Varus (7.9%)
# Rank 3: Ashe (6.0%)
# Rank 4: Ezreal (5.7%)
# Rank 5: Elise (4.5%)
#
# Instance 16:
# True Champion: Elise
# Found in: Rank_3
# Rank 1: Jinx (18.1%)
# Rank 2: Varus (8.0%)
# Rank 3: Elise (6.1%)
# Rank 4: Ashe (5.1%)
# Rank 5: Jhin (3.7%)
#
# Instance 17:
# True Champion: Elise
# Found in: Rank_3
# Rank 1: Varus (8.7%)
# Rank 2: Jinx (7.2%)
# Rank 3: Elise (5.2%)
# Rank 4: Ashe (4.5%)
# Rank 5: Ezreal (4.1%)
#
# Instance 18:
# True Champion: Jarvan IV
# Found in: Not in Top 5
# Rank 1: Jinx (7.2%)
# Rank 2: Kai'Sa (5.7%)
# Rank 3: Ashe (5.3%)
# Rank 4: Elise (5.0%)
# Rank 5: Varus (4.5%)
#
# Instance 19:
# True Champion: Kha'Zix
# Found in: Not in Top 5
# Rank 1: Varus (7.0%)
# Rank 2: Elise (5.9%)
# Rank 3: Jinx (5.9%)
# Rank 4: Ezreal (5.6%)
# Rank 5: Kai'Sa (5.0%)
#
# Instance 20:
# True Champion: Wukong
# Found in: Not in Top 5
# Rank 1: Jinx (14.9%)
# Rank 2: Varus (7.4%)
# Rank 3: Elise (6.9%)
# Rank 4: Jhin (3.4%)
# Rank 5: Ashe (3.2%)
#
# Instance 21:
# True Champion: Hwei
# Found in: Not in Top 5
# Rank 1: Akshan (29.2%)
# Rank 2: Seraphine (4.5%)
# Rank 3: Karthus (4.0%)
# Rank 4: Anivia (3.4%)
# Rank 5: Ivern (3.2%)
#
# Instance 22:
# True Champion: Nautilus
# Found in: Not in Top 5
# Rank 1: Akshan (22.5%)
# Rank 2: Anivia (3.9%)
# Rank 3: Jarvan IV (3.2%)
# Rank 4: Karthus (3.1%)
# Rank 5: Seraphine (2.9%)
#
# Instance 23:
# True Champion: Soraka
# Found in: Not in Top 5
# Rank 1: Akshan (22.8%)
# Rank 2: Ivern (4.3%)
# Rank 3: Seraphine (3.8%)
# Rank 4: Anivia (3.6%)
# Rank 5: Karthus (2.8%)
#
# Instance 24:
# True Champion: Nautilus
# Found in: Not in Top 5
# Rank 1: Akshan (33.6%)
# Rank 2: Seraphine (3.8%)
# Rank 3: Ivern (3.8%)
# Rank 4: Anivia (3.2%)
# Rank 5: Kindred (3.2%)
#
# Instance 25:
# True Champion: Soraka
# Found in: Not in Top 5
# Rank 1: Akshan (32.7%)
# Rank 2: Seraphine (3.5%)
# Rank 3: Ivern (3.4%)
# Rank 4: Anivia (3.2%)
# Rank 5: Karthus (3.1%)
#
# Instance 26:
# True Champion: Soraka
# Found in: Not in Top 5
# Rank 1: Akshan (30.8%)
# Rank 2: Seraphine (3.7%)
# Rank 3: Ivern (3.3%)
# Rank 4: Anivia (3.1%)
# Rank 5: Karthus (3.1%)
#
# Instance 27:
# True Champion: Soraka
# Found in: Not in Top 5
# Rank 1: Akshan (28.4%)
# Rank 2: Seraphine (3.8%)
# Rank 3: Ivern (3.4%)
# Rank 4: Karthus (3.2%)
# Rank 5: Anivia (3.2%)
#
# Instance 28:
# True Champion: Nautilus
# Found in: Not in Top 5
# Rank 1: Akshan (29.1%)
# Rank 2: Ivern (3.7%)
# Rank 3: Seraphine (3.5%)
# Rank 4: Karthus (3.3%)
# Rank 5: Anivia (3.2%)
#
# Instance 29:
# True Champion: Akshan
# Found in: Rank_1
# Rank 1: Akshan (20.3%)
# Rank 2: Seraphine (4.9%)
# Rank 3: Lulu (3.9%)
# Rank 4: Ivern (3.9%)
# Rank 5: Anivia (3.4%)
#
# Instance 30:
# True Champion: Nautilus
# Found in: Not in Top 5
# Rank 1: Akshan (22.0%)
# Rank 2: Lulu (5.2%)
# Rank 3: Anivia (3.5%)
# Rank 4: Karthus (3.3%)
# Rank 5: Kindred (2.8%)
#
# Instance 31:
# True Champion: Akshan
# Found in: Rank_1
# Rank 1: Akshan (30.3%)
# Rank 2: Seraphine (4.8%)
# Rank 3: Ivern (4.4%)
# Rank 4: Anivia (3.3%)
# Rank 5: Karthus (3.2%)
#
# Instance 32:
# True Champion: Akshan
# Found in: Rank_1
# Rank 1: Akshan (29.7%)
# Rank 2: Kindred (4.5%)
# Rank 3: Seraphine (4.3%)
# Rank 4: Ivern (4.2%)
# Rank 5: Anivia (3.4%)
#
# Instance 33:
# True Champion: Akshan
# Found in: Rank_1
# Rank 1: Akshan (21.6%)
# Rank 2: Karthus (3.8%)
# Rank 3: Anivia (3.8%)
# Rank 4: Seraphine (3.3%)
# Rank 5: Ivern (2.8%)
#
# Instance 34:
# True Champion: Akshan
# Found in: Rank_1
# Rank 1: Akshan (31.6%)
# Rank 2: Seraphine (4.6%)
# Rank 3: Ivern (3.6%)
# Rank 4: Anivia (3.3%)
# Rank 5: Karthus (3.0%)
#
# Instance 35:
# True Champion: Hwei
# Found in: Not in Top 5
# Rank 1: Akshan (28.4%)
# Rank 2: Seraphine (4.2%)
# Rank 3: Ivern (3.6%)
# Rank 4: Anivia (3.4%)
# Rank 5: Karthus (3.3%)
#
# Instance 36:
# True Champion: Hwei
# Found in: Not in Top 5
# Rank 1: Akshan (28.5%)
# Rank 2: Ivern (4.6%)
# Rank 3: Seraphine (4.1%)
# Rank 4: Anivia (3.6%)
# Rank 5: Karthus (2.7%)
#
# Instance 37:
# True Champion: Hwei
# Found in: Not in Top 5
# Rank 1: Akshan (28.7%)
# Rank 2: Seraphine (4.8%)
# Rank 3: Ivern (4.5%)
# Rank 4: Anivia (3.3%)
# Rank 5: Karthus (2.4%)
#
# Instance 38:
# True Champion: Akshan
# Found in: Rank_1
# Rank 1: Akshan (27.7%)
# Rank 2: Seraphine (4.3%)
# Rank 3: Ivern (3.6%)
# Rank 4: Anivia (3.3%)
# Rank 5: Karthus (3.0%)
#
# Instance 39:
# True Champion: Hwei
# Found in: Not in Top 5
# Rank 1: Akshan (32.9%)
# Rank 2: Ivern (4.0%)
# Rank 3: Seraphine (3.7%)
# Rank 4: Anivia (3.4%)
# Rank 5: Karthus (2.7%)
#
# Instance 40:
# True Champion: Nautilus
# Found in: Not in Top 5
# Rank 1: Akshan (22.3%)
# Rank 2: Lulu (4.9%)
# Rank 3: Ivern (3.9%)
# Rank 4: Seraphine (3.6%)
# Rank 5: Anivia (3.5%)
#
# Instance 41:
# True Champion: Jayce
# Found in: Rank_3
# Rank 1: Jax (16.6%)
# Rank 2: Gnar (13.4%)
# Rank 3: Jayce (8.8%)
# Rank 4: Aurora (6.5%)
# Rank 5: Irelia (4.5%)
#
# Instance 42:
# True Champion: Gwen
# Found in: Rank_2
# Rank 1: Gnar (12.6%)
# Rank 2: Gwen (12.1%)
# Rank 3: Aurora (7.2%)
# Rank 4: Jax (6.3%)
# Rank 5: Jayce (5.6%)
#
# Instance 43:
# True Champion: Aurora
# Found in: Rank_3
# Rank 1: Gnar (13.1%)
# Rank 2: Jax (10.6%)
# Rank 3: Aurora (6.8%)
# Rank 4: Jayce (6.2%)
# Rank 5: Gwen (5.2%)
#
# Instance 44:
# True Champion: Aurora
# Found in: Rank_2
# Rank 1: Jax (12.0%)
# Rank 2: Aurora (10.6%)
# Rank 3: Jayce (8.1%)
# Rank 4: Irelia (6.3%)
# Rank 5: Rumble (5.6%)
#
# Instance 45:
# True Champion: Gnar
# Found in: Rank_2
# Rank 1: Jax (14.1%)
# Rank 2: Gnar (10.9%)
# Rank 3: Irelia (7.2%)
# Rank 4: Jayce (6.4%)
# Rank 5: Aurora (5.5%)
#
# Instance 46:
# True Champion: Dr. Mundo
# Found in: Not in Top 5
# Rank 1: Gnar (12.2%)
# Rank 2: Jax (9.8%)
# Rank 3: Aurora (8.6%)
# Rank 4: Jayce (8.3%)
# Rank 5: Irelia (7.2%)
#
# Instance 47:
# True Champion: Jax
# Found in: Rank_1
# Rank 1: Jax (10.9%)
# Rank 2: Gnar (10.3%)
# Rank 3: Irelia (8.0%)
# Rank 4: Jayce (5.8%)
# Rank 5: Aurora (5.6%)
#
# Instance 48:
# True Champion: Jax
# Found in: Rank_1
# Rank 1: Jax (22.1%)
# Rank 2: Gnar (9.4%)
# Rank 3: Jayce (6.8%)
# Rank 4: Irelia (4.6%)
# Rank 5: Aurora (3.8%)
#
# Instance 49:
# True Champion: Gnar
# Found in: Rank_2
# Rank 1: Jax (19.8%)
# Rank 2: Gnar (18.3%)
# Rank 3: Aurora (5.5%)
# Rank 4: Irelia (5.1%)
# Rank 5: Jayce (4.8%)
#
# Instance 50:
# True Champion: Irelia
# Found in: Rank_4
# Rank 1: Jayce (12.3%)
# Rank 2: Jax (12.0%)
# Rank 3: Gnar (7.8%)
# Rank 4: Irelia (7.5%)
# Rank 5: Rumble (6.9%)
#
# Instance 51:
# True Champion: Aurora
# Found in: Rank_2
# Rank 1: Jax (10.5%)
# Rank 2: Aurora (9.2%)
# Rank 3: Gnar (7.5%)
# Rank 4: Jayce (6.8%)
# Rank 5: Renekton (6.4%)
#
# Instance 52:
# True Champion: K'Sante
# Found in: Not in Top 5
# Rank 1: Jax (11.3%)
# Rank 2: Gnar (7.0%)
# Rank 3: Aurora (6.1%)
# Rank 4: Jayce (6.0%)
# Rank 5: Irelia (5.9%)
#
# Instance 53:
# True Champion: Jax
# Found in: Rank_1
# Rank 1: Jax (33.0%)
# Rank 2: Gnar (13.1%)
# Rank 3: Jayce (5.9%)
# Rank 4: Aurora (3.1%)
# Rank 5: Ambessa (2.9%)
#
# Instance 54:
# True Champion: Renekton
# Found in: Not in Top 5
# Rank 1: Jax (11.6%)
# Rank 2: Aurora (7.6%)
# Rank 3: Jayce (6.8%)
# Rank 4: Irelia (6.2%)
# Rank 5: Rumble (5.2%)
#
# Instance 55:
# True Champion: Irelia
# Found in: Rank_4
# Rank 1: Gnar (19.1%)
# Rank 2: Jax (11.9%)
# Rank 3: Aurora (5.1%)
# Rank 4: Irelia (5.1%)
# Rank 5: Jayce (4.0%)
#
# Instance 56:
# True Champion: Gnar
# Found in: Rank_1
# Rank 1: Gnar (14.1%)
# Rank 2: Jax (13.8%)
# Rank 3: Aurora (5.9%)
# Rank 4: Jayce (5.6%)
# Rank 5: Irelia (4.6%)
#
# Instance 57:
# True Champion: Gnar
# Found in: Rank_1
# Rank 1: Gnar (21.4%)
# Rank 2: Rumble (8.1%)
# Rank 3: Jax (6.9%)
# Rank 4: Jayce (5.6%)
# Rank 5: Aurora (5.5%)
#
# Instance 58:
# True Champion: Jax
# Found in: Rank_1
# Rank 1: Jax (14.6%)
# Rank 2: Gnar (8.8%)
# Rank 3: Jayce (7.6%)
# Rank 4: Renekton (6.2%)
# Rank 5: Irelia (5.8%)
#
# Instance 59:
# True Champion: Skarner
# Found in: Not in Top 5
# Rank 1: Gnar (9.2%)
# Rank 2: Jax (8.4%)
# Rank 3: Jayce (6.3%)
# Rank 4: Gwen (5.6%)
# Rank 5: Aurora (5.3%)
#
# Instance 60:
# True Champion: Aatrox
# Found in: Not in Top 5
# Rank 1: Jax (10.6%)
# Rank 2: Gnar (6.6%)
# Rank 3: Jayce (6.3%)
# Rank 4: Rumble (6.1%)
# Rank 5: Irelia (5.2%)
#
# Instance 61:
# True Champion: Kalista
# Found in: Not in Top 5
# Rank 1: Jinx (12.3%)
# Rank 2: Jhin (3.9%)
# Rank 3: Ashe (3.4%)
# Rank 4: Varus (3.2%)
# Rank 5: Lee Sin (3.0%)
#
# Instance 62:
# True Champion: Lee Sin
# Found in: Not in Top 5
# Rank 1: Jinx (9.8%)
# Rank 2: Varus (6.2%)
# Rank 3: Ashe (3.8%)
# Rank 4: Caitlyn (3.5%)
# Rank 5: Viktor (3.3%)
#
# Instance 63:
# True Champion: Vi
# Found in: Not in Top 5
# Rank 1: Jinx (12.5%)
# Rank 2: Varus (4.5%)
# Rank 3: Jhin (4.4%)
# Rank 4: Caitlyn (3.9%)
# Rank 5: Lee Sin (3.2%)
#
# Instance 64:
# True Champion: Elise
# Found in: Not in Top 5
# Rank 1: Jinx (5.8%)
# Rank 2: Varus (5.3%)
# Rank 3: Lee Sin (4.7%)
# Rank 4: Jhin (4.0%)
# Rank 5: Ashe (4.0%)
#
# Instance 65:
# True Champion: Caitlyn
# Found in: Rank_4
# Rank 1: Jinx (9.0%)
# Rank 2: Jhin (5.6%)
# Rank 3: Ashe (5.1%)
# Rank 4: Caitlyn (4.4%)
# Rank 5: Varus (3.6%)
#
# Instance 66:
# True Champion: Sejuani
# Found in: Not in Top 5
# Rank 1: Jinx (7.3%)
# Rank 2: Varus (5.1%)
# Rank 3: Ashe (3.6%)
# Rank 4: Jhin (3.4%)
# Rank 5: Lee Sin (3.1%)
#
# Instance 67:
# True Champion: Lee Sin
# Found in: Not in Top 5
# Rank 1: Jinx (6.4%)
# Rank 2: Jhin (4.3%)
# Rank 3: Varus (3.9%)
# Rank 4: Ashe (3.7%)
# Rank 5: Viktor (3.5%)
#
# Instance 68:
# True Champion: Kalista
# Found in: Not in Top 5
# Rank 1: Jinx (4.7%)
# Rank 2: Varus (4.0%)
# Rank 3: Viktor (4.0%)
# Rank 4: Ashe (3.8%)
# Rank 5: Caitlyn (3.8%)
#
# Instance 69:
# True Champion: Kalista
# Found in: Not in Top 5
# Rank 1: Jinx (7.2%)
# Rank 2: Varus (4.4%)
# Rank 3: Jhin (4.3%)
# Rank 4: Ezreal (3.6%)
# Rank 5: Viktor (3.2%)
#
# Instance 70:
# True Champion: Viktor
# Found in: Not in Top 5
# Rank 1: Jinx (10.8%)
# Rank 2: Jhin (5.2%)
# Rank 3: Varus (4.5%)
# Rank 4: Ashe (3.4%)
# Rank 5: Ezreal (3.2%)
#
# Instance 71:
# True Champion: Zyra
# Found in: Not in Top 5
# Rank 1: Jinx (5.3%)
# Rank 2: Jhin (4.4%)
# Rank 3: Varus (3.8%)
# Rank 4: Ashe (3.6%)
# Rank 5: Corki (3.3%)
#
# Instance 72:
# True Champion: Gnar
# Found in: Not in Top 5
# Rank 1: Jinx (5.7%)
# Rank 2: Jhin (4.8%)
# Rank 3: Lee Sin (3.3%)
# Rank 4: Corki (2.7%)
# Rank 5: Ashe (2.6%)
#
# Instance 73:
# True Champion: Smolder
# Found in: Not in Top 5
# Rank 1: Jinx (9.2%)
# Rank 2: Jhin (4.9%)
# Rank 3: Varus (4.0%)
# Rank 4: Ezreal (3.6%)
# Rank 5: Caitlyn (3.5%)
#
# Instance 74:
# True Champion: Yasuo
# Found in: Not in Top 5
# Rank 1: Jinx (9.6%)
# Rank 2: Jhin (5.5%)
# Rank 3: Ezreal (4.9%)
# Rank 4: Ashe (3.4%)
# Rank 5: Lee Sin (2.9%)
#
# Instance 75:
# True Champion: Nocturne
# Found in: Not in Top 5
# Rank 1: Varus (8.5%)
# Rank 2: Jinx (8.2%)
# Rank 3: Viktor (3.4%)
# Rank 4: Lee Sin (3.4%)
# Rank 5: Ezreal (3.0%)
#
# Instance 76:
# True Champion: Samira
# Found in: Not in Top 5
# Rank 1: Jhin (10.8%)
# Rank 2: Jinx (4.6%)
# Rank 3: Caitlyn (3.4%)
# Rank 4: Kai'Sa (3.1%)
# Rank 5: Ashe (2.8%)
#
# Instance 77:
# True Champion: Caitlyn
# Found in: Rank_2
# Rank 1: Jinx (12.8%)
# Rank 2: Caitlyn (5.9%)
# Rank 3: Jhin (3.5%)
# Rank 4: Viktor (3.1%)
# Rank 5: Varus (3.0%)
#
# Instance 78:
# True Champion: Nidalee
# Found in: Not in Top 5
# Rank 1: Jinx (9.8%)
# Rank 2: Jhin (4.3%)
# Rank 3: Varus (3.9%)
# Rank 4: Ashe (3.5%)
# Rank 5: Viktor (3.3%)
#
# Instance 79:
# True Champion: Lee Sin
# Found in: Not in Top 5
# Rank 1: Viktor (4.9%)
# Rank 2: Varus (4.9%)
# Rank 3: Jinx (3.6%)
# Rank 4: Jhin (3.6%)
# Rank 5: Caitlyn (3.2%)
#
# Instance 80:
# True Champion: Kalista
# Found in: Not in Top 5
# Rank 1: Jinx (8.4%)
# Rank 2: Varus (5.2%)
# Rank 3: Jhin (4.5%)
# Rank 4: Ezreal (4.1%)
# Rank 5: Caitlyn (3.6%)
#
# Instance 81:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (24.3%)
# Rank 2: Galio (3.4%)
# Rank 3: Orianna (3.0%)
# Rank 4: Akali (2.7%)
# Rank 5: Aurora (2.3%)
#
# Instance 82:
# True Champion: Ashe
# Found in: Rank_5
# Rank 1: Katarina (20.5%)
# Rank 2: Sylas (5.0%)
# Rank 3: Viktor (4.3%)
# Rank 4: Corki (3.3%)
# Rank 5: Ashe (3.3%)
#
# Instance 83:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (22.2%)
# Rank 2: Viktor (5.0%)
# Rank 3: Sylas (3.7%)
# Rank 4: Aurora (3.2%)
# Rank 5: Orianna (2.5%)
#
# Instance 84:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (24.6%)
# Rank 2: Azir (2.8%)
# Rank 3: Viktor (2.5%)
# Rank 4: Sylas (2.5%)
# Rank 5: Corki (2.4%)
#
# Instance 85:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (21.2%)
# Rank 2: Viktor (5.4%)
# Rank 3: Aurora (3.8%)
# Rank 4: Sylas (3.7%)
# Rank 5: Akali (3.1%)
#
# Instance 86:
# True Champion: Ashe
# Found in: Not in Top 5
# Rank 1: Katarina (21.0%)
# Rank 2: Aurora (2.9%)
# Rank 3: Viktor (2.8%)
# Rank 4: Lissandra (2.5%)
# Rank 5: Corki (2.4%)
#
# Instance 87:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (18.8%)
# Rank 2: Aurora (4.2%)
# Rank 3: Akali (3.9%)
# Rank 4: Sylas (3.3%)
# Rank 5: Viktor (2.5%)
#
# Instance 88:
# True Champion: Kai'Sa
# Found in: Not in Top 5
# Rank 1: Katarina (19.4%)
# Rank 2: Viktor (4.2%)
# Rank 3: Sylas (4.1%)
# Rank 4: Corki (2.9%)
# Rank 5: Aurora (2.8%)
#
# Instance 89:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (23.5%)
# Rank 2: Galio (3.8%)
# Rank 3: Viktor (2.6%)
# Rank 4: Aurora (2.4%)
# Rank 5: Azir (2.2%)
#
# Instance 90:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (20.8%)
# Rank 2: Viktor (3.4%)
# Rank 3: Galio (3.4%)
# Rank 4: Ahri (2.4%)
# Rank 5: Aurora (2.3%)
#
# Instance 91:
# True Champion: Lissandra
# Found in: Rank_5
# Rank 1: Katarina (22.9%)
# Rank 2: Viktor (5.3%)
# Rank 3: Sylas (4.3%)
# Rank 4: Aurora (2.7%)
# Rank 5: Lissandra (2.6%)
#
# Instance 92:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (22.9%)
# Rank 2: Galio (3.2%)
# Rank 3: Sylas (3.0%)
# Rank 4: Orianna (2.9%)
# Rank 5: Akali (2.9%)
#
# Instance 93:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (24.0%)
# Rank 2: Galio (3.4%)
# Rank 3: Corki (2.6%)
# Rank 4: Ahri (2.5%)
# Rank 5: Viktor (2.4%)
#
# Instance 94:
# True Champion: Xerath
# Found in: Not in Top 5
# Rank 1: Katarina (21.0%)
# Rank 2: Viktor (2.5%)
# Rank 3: Lissandra (2.4%)
# Rank 4: Sylas (2.3%)
# Rank 5: Aurora (2.3%)
#
# Instance 95:
# True Champion: Lissandra
# Found in: Rank_5
# Rank 1: Katarina (22.1%)
# Rank 2: Viktor (4.1%)
# Rank 3: Sylas (3.3%)
# Rank 4: Akali (3.3%)
# Rank 5: Lissandra (2.8%)
#
# Instance 96:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (24.2%)
# Rank 2: Sylas (4.8%)
# Rank 3: Viktor (2.7%)
# Rank 4: Aurora (2.6%)
# Rank 5: Corki (2.4%)
#
# Instance 97:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (18.5%)
# Rank 2: Viktor (4.1%)
# Rank 3: Akali (3.4%)
# Rank 4: Aurora (2.9%)
# Rank 5: Sylas (2.6%)
#
# Instance 98:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (24.0%)
# Rank 2: Viktor (2.7%)
# Rank 3: Sylas (2.5%)
# Rank 4: Corki (2.3%)
# Rank 5: Lissandra (2.3%)
#
# Instance 99:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (20.4%)
# Rank 2: Galio (3.9%)
# Rank 3: Viktor (3.1%)
# Rank 4: Lissandra (2.6%)
# Rank 5: Corki (2.5%)
#
# Instance 100:
# True Champion: Katarina
# Found in: Rank_1
# Rank 1: Katarina (20.0%)
# Rank 2: Sylas (3.7%)
# Rank 3: Viktor (3.2%)
# Rank 4: Corki (2.7%)
# Rank 5: Lissandra (2.6%)
